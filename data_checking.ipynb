# %%
from extract_table import create_dataframes
import numpy as np
import pandas as pd

# %%
data=[] 
data=create_dataframes()
# Out:
# HTML Data: <body><table><thead><tr><th colspan="1"></th><th colspan="1"></th><th colspan="1"></th><th colspan="1"></th><th colspan="2">Head</th><th colspan="1"></th><th colspan="1"></th><th colspan="1"></th><th colspan="1"></th><th colspan="1"></th><th colspan="1"></th></tr><tr><td>Lg.</td><td>Threading</td><td>Min.Thread Lg.</td><td>ThreadSpacing</td><td>Dia.</td><td>Ht.</td><td>DriveSize</td><td>TensileStrength, psi</td><td>Specifications Met</td><td>Pkg.Qty.</td><td> </td><td>Pkg.</td></tr></thead><tbod
# Found 89 tables
# DataFrame 1 preview:
#                         0               1               2              3   \
# 0
# 1                      Lg.       Threading  Min.Thread Lg.  ThreadSpacing
# 2                     0-80
# 3  Black-Oxide Alloy Steel
# 4                    1/16"  Fully Threaded              __           Fine
#
#        4      5          6                     7                      8   \
# 0    Head
# 1    Dia.    Ht.  DriveSize  TensileStrength, psi     Specifications Met
# 2
# 3
# 4  0.096"  0.06"     0.050"               170,000  ASME B18.3, ASTM A574
#
#          9          10      11
# 0
# 1  Pkg.Qty.               Pkg.
# 2
# 3
# 4        50  91251A051  $20.00
# DataFrame 2 preview:
#                         0               1               2               3   \
# 0
# 1                      Lg.       Threading  Min.Thread Lg.  Thread Spacing
# 2                     1-64
# 3  Black-Oxide Alloy Steel
# 4                     1/8"  Fully Threaded              __          Coarse
#
#        4       5          6                     7                      8   \
# 0    Head
# 1    Dia.     Ht.  DriveSize  TensileStrength, psi     Specifications Met
# 2
# 3
# 4  0.118"  0.073"      1/16"               170,000  ASME B18.3, ASTM A574
#
#          9          10     11
# 0
# 1  Pkg.Qty.              Pkg.
# 2
# 3
# 4        10  90044A280  $8.79
# DataFrame 3 preview:
#                         0               1               2              3   \
# 0
# 1                      Lg.       Threading  Min.Thread Lg.  ThreadSpacing
# 2                     1-72
# 3  Black-Oxide Alloy Steel
# 4                    1/16"  Fully Threaded              __           Fine
#
#        4       5          6                     7                      8   \
# 0    Head
# 1    Dia.     Ht.  DriveSize  TensileStrength, psi     Specifications Met
# 2
# 3
# 4  0.118"  0.073"      1/16"               170,000  ASME B18.3, ASTM A574
#
#          9          10      11
# 0
# 1  Pkg.Qty.               Pkg.
# 2
# 3
# 4         5  91251A465  $21.15
# DataFrame 4 preview:
#                         0               1               2               3   \
# 0
# 1                      Lg.       Threading  Min.Thread Lg.  Thread Spacing
# 2                     2-56
# 3  Black-Oxide Alloy Steel
# 4                    1/16"  Fully Threaded              __          Coarse
#
#       4       5          6                     7                   8   \
# 0   Head
# 1   Dia.     Ht.  DriveSize  TensileStrength, psi  Specifications Met
# 2
# 3
# 4  9/64"  0.086"      5/64"               170,000           ASTM A574
#
#          9          10      11
# 0
# 1  Pkg.Qty.               Pkg.
# 2
# 3
# 4        25  91251A213  $17.91
# DataFrame 5 preview:
#                         0               1               2              3   \
# 0
# 1                      Lg.       Threading  Min.Thread Lg.  ThreadSpacing
# 2                     2-64
# 3  Black-Oxide Alloy Steel
# 4                     1/8"  Fully Threaded              __           Fine
#
#       4       5          6                     7                  8   \
# 0   Head
# 1   Dia.     Ht.  DriveSize  TensileStrength, psi  SpecificationsMet
# 2
# 3
# 4  9/64"  0.086"      5/64"               170,000          ASTM A574
#
#          9          10      11
# 0
# 1  Pkg.Qty.               Pkg.
# 2
# 3
# 4        25  91251A745  $13.54
# DataFrame 6 preview:
#                         0               1               2               3   \
# 0
# 1                      Lg.       Threading  Min.Thread Lg.  Thread Spacing
# 2                     3-48
# 3  Black-Oxide Alloy Steel
# 4                     1/8"  Fully Threaded              __          Coarse
#
#        4       5          6                     7                  8   \
# 0    Head
# 1    Dia.     Ht.  DriveSize  TensileStrength, psi  SpecificationsMet
# 2
# 3
# 4  0.161"  0.099"      5/64"               170,000          ASTM A574
#
#          9          10      11
# 0
# 1  Pkg.Qty.               Pkg.
# 2
# 3
# 4        10  91251A228  $12.52
# DataFrame 7 preview:
#                         0               1               2              3   \
# 0
# 1                      Lg.       Threading  Min.Thread Lg.  ThreadSpacing
# 2                     3-56
# 3  Black-Oxide Alloy Steel
# 4                     1/8"  Fully Threaded              __           Fine
#
#        4       5          6                     7                  8   \
# 0    Head
# 1    Dia.     Ht.  DriveSize  TensileStrength, psi  SpecificationsMet
# 2
# 3
# 4  0.161"  0.099"      5/64"               170,000          ASTM A574
#
#          9          10      11
# 0
# 1  Pkg.Qty.               Pkg.
# 2
# 3
# 4        10  90044A244  $15.05
# DataFrame 8 preview:
#                         0               1               2               3   \
# 0
# 1                      Lg.       Threading  Min.Thread Lg.  Thread Spacing
# 2                     4-40
# 3  Black-Oxide Alloy Steel
# 4                    3/32"  Fully Threaded              __          Coarse
#
#        4       5          6                     7                   8   \
# 0    Head
# 1    Dia.     Ht.  DriveSize  TensileStrength, psi  Specifications Met
# 2
# 3
# 4  0.183"  0.112"      3/32"               170,000           ASTM A574
#
#          9          10     11
# 0
# 1  Pkg.Qty.              Pkg.
# 2
# 3
# 4        10  91251A231  $9.90
# DataFrame 9 preview:
#                         0               1               2              3   \
# 0
# 1                      Lg.       Threading  Min.Thread Lg.  ThreadSpacing
# 2                     4-48
# 3  Black-Oxide Alloy Steel
# 4                     1/8"  Fully Threaded              __           Fine
#
#        4       5          6                     7                   8   \
# 0    Head
# 1    Dia.     Ht.  DriveSize  TensileStrength, psi  Specifications Met
# 2
# 3
# 4  0.183"  0.112"      3/32"               170,000           ASTM A574
#
#          9          10     11
# 0
# 1  Pkg.Qty.              Pkg.
# 2
# 3
# 4        10  91251A234  $9.03
# DataFrame 10 preview:
#                         0               1               2               3   \
# 0
# 1                      Lg.       Threading  Min.Thread Lg.  Thread Spacing
# 2                     5-40
# 3  Black-Oxide Alloy Steel
# 4                    3/32"  Fully Threaded              __          Coarse
#
#        4     5          6                     7                   8   \
# 0    Head
# 1    Dia.   Ht.  DriveSize  TensileStrength, psi  Specifications Met
# 2
# 3
# 4  0.205"  1/8"      3/32"               170,000           ASTM A574
#
#          9          10     11
# 0
# 1  Pkg.Qty.              Pkg.
# 2
# 3
# 4        10  91251A243  $9.99
# DataFrame 11 preview:
#                         0               1               2              3   \
# 0
# 1                      Lg.       Threading  Min.Thread Lg.  ThreadSpacing
# 2                     5-44
# 3  Black-Oxide Alloy Steel
# 4                     1/4"  Fully Threaded              __           Fine
#
#        4     5          6                     7                  8         9   \
# 0    Head
# 1    Dia.   Ht.  DriveSize  TensileStrength, psi  SpecificationsMet  Pkg.Qty.
# 2
# 3
# 4  0.205"  1/8"      3/32"               170,000          ASTM A574        10
#
#           10      11
# 0
# 1               Pkg.
# 2
# 3
# 4  90044A252  $10.59
# DataFrame 12 preview:
#                         0               1               2               3   \
# 0
# 1                      Lg.       Threading  Min.Thread Lg.  Thread Spacing
# 2                     6-32
# 3  Black-Oxide Alloy Steel
# 4                    3/32"  Fully Threaded              __          Coarse
#
#        4       5          6                     7                   8   \
# 0    Head
# 1    Dia.     Ht.  DriveSize  TensileStrength, psi  Specifications Met
# 2
# 3
# 4  0.226"  0.138"      7/64"               170,000           ASTM A574
#
#          9          10      11
# 0
# 1  Pkg.Qty.               Pkg.
# 2
# 3
# 4        10  91251A268  $13.78
# DataFrame 13 preview:
#                         0               1               2              3   \
# 0
# 1                      Lg.       Threading  Min.Thread Lg.  ThreadSpacing
# 2                     6-40
# 3  Black-Oxide Alloy Steel
# 4                    3/16"  Fully Threaded              __           Fine
#
#        4       5          6                     7                   8   \
# 0    Head
# 1    Dia.     Ht.  DriveSize  TensileStrength, psi  Specifications Met
# 2
# 3
# 4  0.226"  0.138"      7/64"               170,000           ASTM A574
#
#          9          10     11
# 0
# 1  Pkg.Qty.              Pkg.
# 2
# 3
# 4        10  91864A042  $7.58
# DataFrame 14 preview:
#                         0               1               2               3   \
# 0
# 1                      Lg.       Threading  Min.Thread Lg.  Thread Spacing
# 2                     8-32
# 3  Black-Oxide Alloy Steel
# 4                    3/32"  Fully Threaded              __          Coarse
#
#       4       5          6                     7                   8   \
# 0   Head
# 1   Dia.     Ht.  DriveSize  TensileStrength, psi  Specifications Met
# 2
# 3
# 4  0.27"  0.164"      9/64"               170,000           ASTM A574
#
#          9          10     11
# 0
# 1  Pkg.Qty.              Pkg.
# 2
# 3
# 4        10  91251A271  $8.42
# DataFrame 15 preview:
#                         0               1               2              3   \
# 0
# 1                      Lg.       Threading  Min.Thread Lg.  ThreadSpacing
# 2                     8-36
# 3  Black-Oxide Alloy Steel
# 4                     1/4"  Fully Threaded              __           Fine
#
#       4       5          6                     7                   8   \
# 0   Head
# 1   Dia.     Ht.  DriveSize  TensileStrength, psi  Specifications Met
# 2
# 3
# 4  0.27"  0.164"      9/64"               170,000           ASTM A574
#
#          9          10      11
# 0
# 1  Pkg.Qty.               Pkg.
# 2
# 3
# 4        50  91251A491  $10.08
# DataFrame 16 preview:
#                         0               1               2               3   \
# 0
# 1                      Lg.       Threading  Min.Thread Lg.  Thread Spacing
# 2                    10-24
# 3  Black-Oxide Alloy Steel
# 4                    5/32"  Fully Threaded              __          Coarse
#
#       4      5          6                     7                      8   \
# 0   Head
# 1   Dia.    Ht.  DriveSize  TensileStrength, psi     Specifications Met
# 2
# 3
# 4  5/16"  0.19"      5/32"               170,000  ASME B18.3, ASTM A574
#
#          9          10      11
# 0
# 1  Pkg.Qty.               Pkg.
# 2
# 3
# 4         5  91251A517  $15.29
# DataFrame 17 preview:
#                         0               1               2              3   \
# 0
# 1                      Lg.       Threading  Min.Thread Lg.  ThreadSpacing
# 2                    10-32
# 3  Black-Oxide Alloy Steel
# 4                    5/32"  Fully Threaded              __           Fine
#
#       4      5          6                     7                      8   \
# 0   Head
# 1   Dia.    Ht.  DriveSize  TensileStrength, psi     Specifications Met
# 2
# 3
# 4  5/16"  0.19"      5/32"               170,000  ASME B18.3, ASTM A574
#
#          9          10      11
# 0
# 1  Pkg.Qty.               Pkg.
# 2
# 3
# 4         5  91251A518  $17.60
# DataFrame 18 preview:
#                         0               1               2               3   \
# 0
# 1                      Lg.       Threading  Min.Thread Lg.  Thread Spacing
# 2                    12-24
# 3  Black-Oxide Alloy Steel
# 4                     1/4"  Fully Threaded              __          Coarse
#
#        4       5          6                     7                  8   \
# 0    Head
# 1    Dia.     Ht.  DriveSize  TensileStrength, psi  SpecificationsMet
# 2
# 3
# 4  0.324"  0.216"      5/32"               170,000          ASTM A574
#
#          9          10     11
# 0
# 1  Pkg.Qty.              Pkg.
# 2
# 3
# 4         5  91251A290  $7.78
# DataFrame 19 preview:
#                         0               1               2               3   \
# 0
# 1                      Lg.       Threading  Min.Thread Lg.  Thread Spacing
# 2                  1/4"-20
# 3  Black-Oxide Alloy Steel
# 4                     1/4"  Fully Threaded              __          Coarse
#
#      4     5          6                     7                   8         9   \
# 0  Head
# 1  Dia.   Ht.  DriveSize  TensileStrength, psi  Specifications Met  Pkg.Qty.
# 2
# 3
# 4  3/8"  1/4"      3/16"               170,000           ASTM A574        50
#
#           10      11
# 0
# 1               Pkg.
# 2
# 3
# 4  91251A533  $13.71
# DataFrame 20 preview:
#                         0               1               2              3   \
# 0
# 1                      Lg.       Threading  Min.Thread Lg.  ThreadSpacing
# 2                  1/4"-28
# 3  Black-Oxide Alloy Steel
# 4                     1/4"  Fully Threaded              __           Fine
#
#      4     5          6                     7                   8         9   \
# 0  Head
# 1  Dia.   Ht.  DriveSize  TensileStrength, psi  Specifications Met  Pkg.Qty.
# 2
# 3
# 4  3/8"  1/4"      3/16"               170,000           ASTM A574        50
#
#           10      11
# 0
# 1               Pkg.
# 2
# 3
# 4  91251A462  $17.64
# DataFrame 21 preview:
#                         0               1               2     3     4   \
# 0                                                           Head
# 1                      Lg.       Threading  Thread Spacing  Dia.   Ht.
# 2                  1/4"-32
# 3  Black-Oxide Alloy Steel
# 4                     5/8"  Fully Threaded      Extra Fine  3/8"  1/4"
#
#           5                     6                  7         8          9   \
# 0
# 1  DriveSize  TensileStrength, psi  SpecificationsMet  Pkg.Qty.
# 2
# 3
# 4      3/16"               170,000          ASTM A574         5  90044A203
#
#        10
# 0
# 1    Pkg.
# 2
# 3
# 4  $19.34
# DataFrame 22 preview:
#                         0               1               2               3   \
# 0
# 1                      Lg.       Threading  Min.Thread Lg.  Thread Spacing
# 2                 5/16"-18
# 3  Black-Oxide Alloy Steel
# 4                     1/4"  Fully Threaded              __          Coarse
#
#        4      5          6                     7                   8   \
# 0    Head
# 1    Dia.    Ht.  DriveSize  TensileStrength, psi  Specifications Met
# 2
# 3
# 4  15/32"  5/16"       1/4"               170,000           ASTM A574
#
#          9          10      11
# 0
# 1  Pkg.Qty.               Pkg.
# 2
# 3
# 4        10  91251A575  $10.16
# DataFrame 23 preview:
#                         0               1               2              3   \
# 0
# 1                      Lg.       Threading  Min.Thread Lg.  ThreadSpacing
# 2                 5/16"-24
# 3  Black-Oxide Alloy Steel
# 4                     1/2"  Fully Threaded              __           Fine
#
#        4      5          6                     7                   8   \
# 0    Head
# 1    Dia.    Ht.  DriveSize  TensileStrength, psi  Specifications Met
# 2
# 3
# 4  15/32"  5/16"       1/4"               170,000           ASTM A574
#
#          9          10      11
# 0
# 1  Pkg.Qty.               Pkg.
# 2
# 3
# 4        50  91251A378  $15.72
# DataFrame 24 preview:
#                         0               1               2       3      4   \
# 0                                                             Head
# 1                      Lg.       Threading  Thread Spacing    Dia.    Ht.
# 2                 5/16"-32
# 3  Black-Oxide Alloy Steel
# 4                     3/4"  Fully Threaded      Extra Fine  15/32"  5/16"
#
#           5                     6                  7         8          9   \
# 0
# 1  DriveSize  TensileStrength, psi  SpecificationsMet  Pkg.Qty.
# 2
# 3
# 4       1/4"               170,000          ASTM A574         5  90044A207
#
#        10
# 0
# 1    Pkg.
# 2
# 3
# 4  $19.49
# DataFrame 25 preview:
#                         0               1               2               3   \
# 0
# 1                      Lg.       Threading  Min.Thread Lg.  Thread Spacing
# 2                  3/8"-16
# 3  Black-Oxide Alloy Steel
# 4                     3/8"  Fully Threaded              __          Coarse
#
#       4     5          6                     7                   8         9   \
# 0   Head
# 1   Dia.   Ht.  DriveSize  TensileStrength, psi  Specifications Met  Pkg.Qty.
# 2
# 3
# 4  9/16"  3/8"      5/16"               170,000           ASTM A574        10
#
#           10      11
# 0
# 1               Pkg.
# 2
# 3
# 4  91251A663  $11.41
# DataFrame 26 preview:
#                         0               1               2              3   \
# 0
# 1                      Lg.       Threading  Min.Thread Lg.  ThreadSpacing
# 2                  3/8"-24
# 3  Black-Oxide Alloy Steel
# 4                     3/8"  Fully Threaded              __           Fine
#
#       4     5          6                     7                   8         9   \
# 0   Head
# 1   Dia.   Ht.  DriveSize  TensileStrength, psi  Specifications Met  Pkg.Qty.
# 2
# 3
# 4  9/16"  3/8"      5/16"               170,000           ASTM A574        10
#
#           10      11
# 0
# 1               Pkg.
# 2
# 3
# 4  91251A420  $11.28
# DataFrame 27 preview:
#                         0               1               2               3   \
# 0
# 1                      Lg.       Threading  Min.Thread Lg.  Thread Spacing
# 2                 7/16"-14
# 3  Black-Oxide Alloy Steel
# 4                     3/8"  Fully Threaded              __          Coarse
#
#        4      5          6                     7                   8   \
# 0    Head
# 1    Dia.    Ht.  DriveSize  TensileStrength, psi  Specifications Met
# 2
# 3
# 4  21/32"  7/16"       3/8"               170,000           ASTM A574
#
#          9          10     11
# 0
# 1  Pkg.Qty.              Pkg.
# 2
# 3
# 4        10  91251A363  $7.75
# DataFrame 28 preview:
#                         0               1               2              3   \
# 0
# 1                      Lg.       Threading  Min.Thread Lg.  ThreadSpacing
# 2                 7/16"-20
# 3  Black-Oxide Alloy Steel
# 4                     3/8"  Fully Threaded              __           Fine
#
#        4      5          6                     7                   8   \
# 0    Head
# 1    Dia.    Ht.  DriveSize  TensileStrength, psi  Specifications Met
# 2
# 3
# 4  21/32"  7/16"       3/8"               170,000           ASTM A574
#
#          9          10      11
# 0
# 1  Pkg.Qty.               Pkg.
# 2
# 3
# 4         5  91251A366  $15.05
# DataFrame 29 preview:
#                         0               1               2               3   \
# 0
# 1                      Lg.       Threading  Min.Thread Lg.  Thread Spacing
# 2                  1/2"-13
# 3  Black-Oxide Alloy Steel
# 4                     1/2"  Fully Threaded              __          Coarse
#
#      4     5          6                     7                   8         9   \
# 0  Head
# 1  Dia.   Ht.  DriveSize  TensileStrength, psi  Specifications Met  Pkg.Qty.
# 2
# 3
# 4  3/4"  1/2"       3/8"               170,000           ASTM A574        10
#
#           10      11
# 0
# 1               Pkg.
# 2
# 3
# 4  91251A707  $13.39
# DataFrame 30 preview:
#                         0               1               2              3   \
# 0
# 1                      Lg.       Threading  Min.Thread Lg.  ThreadSpacing
# 2                  1/2"-20
# 3  Black-Oxide Alloy Steel
# 4                     1/2"  Fully Threaded              __           Fine
#
#      4     5          6                     7                   8         9   \
# 0  Head
# 1  Dia.   Ht.  DriveSize  TensileStrength, psi  Specifications Met  Pkg.Qty.
# 2
# 3
# 4  3/4"  1/2"       3/8"               170,000           ASTM A574         5
#
#           10     11
# 0
# 1              Pkg.
# 2
# 3
# 4  91251A965  $7.28
# DataFrame 31 preview:
#                         0               1               2               3   \
# 0
# 1                      Lg.       Threading  Min.Thread Lg.  Thread Spacing
# 2                 9/16"-12
# 3  Black-Oxide Alloy Steel
# 4                       1"  Fully Threaded              __          Coarse
#
#        4      5          6                     7                  8   \
# 0    Head
# 1    Dia.    Ht.  DriveSize  TensileStrength, psi  SpecificationsMet
# 2
# 3
# 4  27/32"  9/16"      7/16"               170,000          ASTM A574
#
#          9          10     11
# 0
# 1  Pkg.Qty.              Pkg.
# 2
# 3
# 4         1  91251A753  $3.34
# DataFrame 32 preview:
#                         0               1               2              3   \
# 0
# 1                      Lg.       Threading  Min.Thread Lg.  ThreadSpacing
# 2                 9/16"-18
# 3  Black-Oxide Alloy Steel
# 4                     3/4"  Fully Threaded              __           Fine
#
#        4      5          6                     7                  8   \
# 0    Head
# 1    Dia.    Ht.  DriveSize  TensileStrength, psi  SpecificationsMet
# 2
# 3
# 4  27/32"  9/16"      7/16"               170,000          ASTM A574
#
#          9          10     11
# 0
# 1  Pkg.Qty.              Pkg.
# 2
# 3
# 4         1  91251A696  $9.10
# DataFrame 33 preview:
#                         0               1               2               3   \
# 0
# 1                      Lg.       Threading  Min.Thread Lg.  Thread Spacing
# 2                  5/8"-11
# 3  Black-Oxide Alloy Steel
# 4                     1/2"  Fully Threaded              __          Coarse
#
#        4     5          6                     7                   8   \
# 0    Head
# 1    Dia.   Ht.  DriveSize  TensileStrength, psi  Specifications Met
# 2
# 3
# 4  15/16"  5/8"       1/2"               170,000           ASTM A574
#
#          9          10     11
# 0
# 1  Pkg.Qty.              Pkg.
# 2
# 3
# 4         1  91251A791  $3.57
# DataFrame 34 preview:
#                         0               1               2              3   \
# 0
# 1                      Lg.       Threading  Min.Thread Lg.  ThreadSpacing
# 2                  5/8"-18
# 3  Black-Oxide Alloy Steel
# 4                     3/4"  Fully Threaded              __           Fine
#
#        4     5          6                     7                   8   \
# 0    Head
# 1    Dia.   Ht.  DriveSize  TensileStrength, psi  Specifications Met
# 2
# 3
# 4  15/16"  5/8"       1/2"               170,000           ASTM A574
#
#          9          10     11
# 0
# 1  Pkg.Qty.              Pkg.
# 2
# 3
# 4         1  91864A055  $8.25
# DataFrame 35 preview:
#                         0               1               2               3   \
# 0
# 1                      Lg.       Threading  Min.Thread Lg.  Thread Spacing
# 2                  3/4"-10
# 3  Black-Oxide Alloy Steel
# 4                     3/4"  Fully Threaded              __          Coarse
#
#        4     5          6                     7                      8   \
# 0    Head
# 1    Dia.   Ht.  DriveSize  TensileStrength, psi     Specifications Met
# 2
# 3
# 4  1 1/8"  3/4"       5/8"               170,000  ASME B18.3, ASTM A574
#
#          9          10      11
# 0
# 1  Pkg.Qty.               Pkg.
# 2
# 3
# 4         1  91251A833  $10.45
# DataFrame 36 preview:
#                         0               1               2              3   \
# 0
# 1                      Lg.       Threading  Min.Thread Lg.  ThreadSpacing
# 2                  3/4"-16
# 3  Black-Oxide Alloy Steel
# 4                   1 1/4"  Fully Threaded              __           Fine
#
#        4     5          6                     7                  8         9   \
# 0    Head
# 1    Dia.   Ht.  DriveSize  TensileStrength, psi  SpecificationsMet  Pkg.Qty.
# 2
# 3
# 4  1 1/8"  3/4"       5/8"               170,000          ASTM A574         1
#
#           10     11
# 0
# 1              Pkg.
# 2
# 3
# 4  91251A041  $4.18
# DataFrame 37 preview:
#                         0               1               2               3   \
# 0
# 1                      Lg.       Threading  Min.Thread Lg.  Thread Spacing
# 2                   7/8"-9
# 3  Black-Oxide Alloy Steel
# 4                   1 1/4"  Fully Threaded              __          Coarse
#
#         4     5          6                     7                      8   \
# 0     Head
# 1     Dia.   Ht.  DriveSize  TensileStrength, psi     Specifications Met
# 2
# 3
# 4  1 5/16"  7/8"       3/4"               170,000  ASME B18.3, ASTM A574
#
#          9          10     11
# 0
# 1  Pkg.Qty.              Pkg.
# 2
# 3
# 4         1  91251A877  $8.60
# DataFrame 38 preview:
#                         0               1               2              3   \
# 0
# 1                      Lg.       Threading  Min.Thread Lg.  ThreadSpacing
# 2                  7/8"-14
# 3  Black-Oxide Alloy Steel
# 4                   2 1/4"  Fully Threaded              __           Fine
#
#         4     5          6                     7                  8   \
# 0     Head
# 1     Dia.   Ht.  DriveSize  TensileStrength, psi  SpecificationsMet
# 2
# 3
# 4  1 5/16"  7/8"       3/4"               170,000          ASTM A574
#
#          9          10     11
# 0
# 1  Pkg.Qty.              Pkg.
# 2
# 3
# 4         1  91251A307  $7.96
# DataFrame 39 preview:
#                         0               1               2               3   \
# 0
# 1                      Lg.       Threading  Min.Thread Lg.  Thread Spacing
# 2                     1"-8
# 3  Black-Oxide Alloy Steel
# 4                   1 1/2"  Fully Threaded              __          Coarse
#
#        4    5          6                     7                   8         9   \
# 0    Head
# 1    Dia.  Ht.  DriveSize  TensileStrength, psi  Specifications Met  Pkg.Qty.
# 2
# 3
# 4  1 1/2"   1"       3/4"               170,000           ASTM A574         1
#
#           10      11
# 0
# 1               Pkg.
# 2
# 3
# 4  91251A909  $13.02
# DataFrame 40 preview:
#                         0               1               2              3   \
# 0
# 1                      Lg.       Threading  Min.Thread Lg.  ThreadSpacing
# 2                    1"-12
# 3  Black-Oxide Alloy Steel
# 4                       2"  Fully Threaded              __           Fine
#
#        4    5          6                     7                  8         9   \
# 0    Head
# 1    Dia.  Ht.  DriveSize  TensileStrength, psi  SpecificationsMet  Pkg.Qty.
# 2
# 3
# 4  1 1/2"   1"       3/4"               170,000          ASTM A574         1
#
#           10      11
# 0
# 1               Pkg.
# 2
# 3
# 4  90044A270  $12.66
# DataFrame 41 preview:
#                         0               1               2              3   \
# 0
# 1                      Lg.       Threading  Min.Thread Lg.  ThreadSpacing
# 2                    1"-14
# 3  Black-Oxide Alloy Steel
# 4                       2"  Fully Threaded              __           Fine
#
#        4    5          6                     7                  8         9   \
# 0    Head
# 1    Dia.  Ht.  DriveSize  TensileStrength, psi  SpecificationsMet  Pkg.Qty.
# 2
# 3
# 4  1 1/2"   1"       3/4"               170,000          ASTM A574         1
#
#           10     11
# 0
# 1              Pkg.
# 2
# 3
# 4  91251A416  $9.15
# DataFrame 42 preview:
#                         0               1               2               3   \
# 0
# 1                      Lg.       Threading  Min.Thread Lg.  Thread Spacing
# 2                 1 1/8"-7
# 3  Black-Oxide Alloy Steel
# 4                       3"  Fully Threaded              __          Coarse
#
#          4       5          6                     7                  8   \
# 0      Head
# 1      Dia.     Ht.  DriveSize  TensileStrength, psi  SpecificationsMet
# 2
# 3
# 4  1 11/16"  1 1/8"       7/8"               170,000          ASTM A574
#
#          9          10      11
# 0
# 1  Pkg.Qty.               Pkg.
# 2
# 3
# 4         1  91251A163  $24.01
# DataFrame 43 preview:
#                         0               1               2              3   \
# 0
# 1                      Lg.       Threading  Min.Thread Lg.  ThreadSpacing
# 2                1 1/8"-12
# 3  Black-Oxide Alloy Steel
# 4                       3"  Fully Threaded              __           Fine
#
#          4       5          6                     7                  8   \
# ...
# 3  Black-Oxide Class 12.9 Alloy Steel
# 4                                  30  Fully Threaded                  __
#
#               3        4       5              6                     7   \
# 0                    Head
# 1  ThreadSpacing  Dia.,mm  Ht.,mm  DriveSize, mm  TensileStrength, psi
# 2
# 3
# 4           Fine       24      16             14               170,000
#
#                    8         9          10      11
# 0
# 1  Specifications Met  Pkg.Qty.               Pkg.
# 2
# 3
# 4  DIN 912, ISO 21269         5  96144A331  $12.96
# DataFrame 78 preview:
#                                    0               1                   2   \
# 0
# 1                              Lg.,mm       Threading  Min. ThreadLg., mm
# 2                          M16 × 2 mm
# 3  Black-Oxide Class 12.9 Alloy Steel
# 4                                  20  Fully Threaded                  __
#
#                3        4       5              6                     7   \
# 0                     Head
# 1  Thread Spacing  Dia.,mm  Ht.,mm  DriveSize, mm  TensileStrength, psi
# 2
# 3
# 4          Coarse       24      16             14               170,000
#
#                    8         9          10     11
# 0
# 1  Specifications Met  Pkg.Qty.              Pkg.
# 2
# 3
# 4   DIN 912, ISO 4762         5  91290A786  $8.25
# DataFrame 79 preview:
#                                    0               1                   2   \
# 0
# 1                              Lg.,mm       Threading  Min. ThreadLg., mm
# 2                        M18 × 2.5 mm
# 3  Black-Oxide Class 12.9 Alloy Steel
# 4                                  30  Fully Threaded                  __
#
#                3        4       5              6                     7   \
# 0                     Head
# 1  Thread Spacing  Dia.,mm  Ht.,mm  DriveSize, mm  TensileStrength, psi
# 2
# 3
# 4          Coarse       27      18             14               170,000
#
#                    8         9          10      11
# 0
# 1  Specifications Met  Pkg.Qty.               Pkg.
# 2
# 3
# 4   DIN 912, ISO 4762         5  91290A030  $12.40
# DataFrame 80 preview:
#                                    0               1                   2   \
# 0
# 1                              Lg.,mm       Threading  Min. ThreadLg., mm
# 2                        M20 × 1.5 mm
# 3  Black-Oxide Class 12.9 Alloy Steel
# 4                                  50  Fully Threaded                  __
#
#                3        4       5              6                     7   \
# 0                     Head
# 1  Thread Spacing  Dia.,mm  Ht.,mm  DriveSize, mm  TensileStrength, psi
# 2
# 3
# 4      Extra Fine       30      20             17               170,000
#
#                    8         9          10     11
# 0
# 1  Specifications Met  Pkg.Qty.              Pkg.
# 2
# 3
# 4  DIN 912, ISO 21269         1  96144A343  $6.67
# DataFrame 81 preview:
#                                    0               1                   2   \
# 0
# 1                              Lg.,mm       Threading  Min. ThreadLg., mm
# 2                        M20 × 2.5 mm
# 3  Black-Oxide Class 12.9 Alloy Steel
# 4                                  25  Fully Threaded                  __
#
#                3        4       5              6                     7   \
# 0                     Head
# 1  Thread Spacing  Dia.,mm  Ht.,mm  DriveSize, mm  TensileStrength, psi
# 2
# 3
# 4          Coarse       30      20             17               170,000
#
#                    8         9          10     11
# 0
# 1  Specifications Met  Pkg.Qty.              Pkg.
# 2
# 3
# 4   DIN 912, ISO 4762         1  91290A131  $3.69
# DataFrame 82 preview:
#                                    0               1                   2   \
# 0
# 1                              Lg.,mm       Threading  Min. ThreadLg., mm
# 2                        M22 × 2.5 mm
# 3  Black-Oxide Class 12.9 Alloy Steel
# 4                                  40  Fully Threaded                  __
#
#                3        4       5              6                     7   \
# 0                     Head
# 1  Thread Spacing  Dia.,mm  Ht.,mm  DriveSize, mm  TensileStrength, psi
# 2
# 3
# 4          Coarse       33      22             17               170,000
#
#                    8         9          10     11
# 0
# 1  Specifications Met  Pkg.Qty.              Pkg.
# 2
# 3
# 4   DIN 912, ISO 4762         1  91290A963  $4.69
# DataFrame 83 preview:
#                                    0               1                   2   \
# 0
# 1                              Lg.,mm       Threading  Min. ThreadLg., mm
# 2                          M24 × 3 mm
# 3  Black-Oxide Class 12.9 Alloy Steel
# 4                                  40  Fully Threaded                  __
#
#                3        4       5              6                     7   \
# 0                     Head
# 1  Thread Spacing  Dia.,mm  Ht.,mm  DriveSize, mm  TensileStrength, psi
# 2
# 3
# 4          Coarse       36      24             19               170,000
#
#                    8         9          10     11
# 0
# 1  Specifications Met  Pkg.Qty.              Pkg.
# 2
# 3
# 4   DIN 912, ISO 4762         1  91290A091  $4.77
# DataFrame 84 preview:
#                                    0               1                   2   \
# 0
# 1                              Lg.,mm       Threading  Min. ThreadLg., mm
# 2                          M27 × 3 mm
# 3  Black-Oxide Class 12.9 Alloy Steel
# 4                                  60  Fully Threaded                  __
#
#                3        4       5              6                     7   \
# 0                     Head
# 1  Thread Spacing  Dia.,mm  Ht.,mm  DriveSize, mm  TensileStrength, psi
# 2
# 3
# 4          Coarse       40      27             19               170,000
#
#                    8         9          10     11
# 0
# 1  Specifications Met  Pkg.Qty.              Pkg.
# 2
# 3
# 4   DIN 912, ISO 4762         1  91290A271  $9.51
# DataFrame 85 preview:
#                                    0               1                   2   \
# 0
# 1                              Lg.,mm       Threading  Min. ThreadLg., mm
# 2                        M30 × 3.5 mm
# 3  Black-Oxide Class 12.9 Alloy Steel
# 4                                  50  Fully Threaded                  __
#
#                3        4       5              6                     7   \
# 0                     Head
# 1  Thread Spacing  Dia.,mm  Ht.,mm  DriveSize, mm  TensileStrength, psi
# 2
# 3
# 4          Coarse       45      30             22               170,000
#
#                    8         9          10      11
# 0
# 1  Specifications Met  Pkg.Qty.               Pkg.
# 2
# 3
# 4   DIN 912, ISO 4762         1  91290A379  $12.80
# DataFrame 86 preview:
#                                    0               1                   2   \
# 0
# 1                              Lg.,mm       Threading  Min. ThreadLg., mm
# 2                        M33 × 3.5 mm
# 3  Black-Oxide Class 12.9 Alloy Steel
# 4                                 100  Fully Threaded                  __
#
#                3        4       5              6                     7   \
# 0                     Head
# 1  Thread Spacing  Dia.,mm  Ht.,mm  DriveSize, mm  TensileStrength, psi
# 2
# 3
# 4          Coarse       50      33             24               170,000
#
#                    8         9          10      11
# 0
# 1  Specifications Met  Pkg.Qty.               Pkg.
# 2
# 3
# 4   DIN 912, ISO 4762         1  91290A283  $18.66
# DataFrame 87 preview:
#                                    0               1                   2   \
# 0
# 1                              Lg.,mm       Threading  Min. ThreadLg., mm
# 2                          M36 × 4 mm
# 3  Black-Oxide Class 12.9 Alloy Steel
# 4                                  60  Fully Threaded                  __
#
#                3        4       5              6                     7   \
# 0                     Head
# 1  Thread Spacing  Dia.,mm  Ht.,mm  DriveSize, mm  TensileStrength, psi
# 2
# 3
# 4          Coarse       54      36             27               170,000
#
#                    8         9          10      11
# 0
# 1  Specifications Met  Pkg.Qty.               Pkg.
# 2
# 3
# 4   DIN 912, ISO 4762         1  91290A151  $26.77
# DataFrame 88 preview:
#                                    0               1                   2   \
# 0
# 1                              Lg.,mm       Threading  Min. ThreadLg., mm
# 2                        M42 × 4.5 mm
# 3  Black-Oxide Class 12.9 Alloy Steel
# 4                                 100  Fully Threaded                  __
#
#                3        4       5              6                     7   \
# 0                     Head
# 1  Thread Spacing  Dia.,mm  Ht.,mm  DriveSize, mm  TensileStrength, psi
# 2
# 3
# 4          Coarse       63      42             32               170,000
#
#                    8         9          10      11
# 0
# 1  Specifications Met  Pkg.Qty.               Pkg.
# 2
# 3
# 4   DIN 912, ISO 4762         1  91290A287  $27.44
# DataFrame 89 preview:
#                                    0                   1                   2   \
# 0
# 1                              Lg.,mm           Threading  Min. ThreadLg., mm
# 2                          M48 × 5 mm
# 3  Black-Oxide Class 12.9 Alloy Steel
# 4                                 140  Partially Threaded                 108
#
#                3        4       5              6                     7   \
# 0                     Head
# 1  Thread Spacing  Dia.,mm  Ht.,mm  DriveSize, mm  TensileStrength, psi
# 2
# 3
# 4          Coarse       72      48             36               170,000
#
#                    8         9          10      11
# 0
# 1  Specifications Met  Pkg.Qty.               Pkg.
# 2
# 3
# 4   DIN 912, ISO 4762         1  91290A156  $76.96

# %%
data[0].shape
# Out:
# (22, 12)

# %%
data[3].head(10)
# Out:
#                         0               1               2               3   \
# 0
# 1                      Lg.       Threading  Min.Thread Lg.  Thread Spacing
# 2                     2-56
# 3  Black-Oxide Alloy Steel
# 4                    1/16"  Fully Threaded              __          Coarse
# 5                    3/32"  Fully Threaded              __          Coarse
# 6                     1/8"  Fully Threaded              __          Coarse
# 7                    5/32"  Fully Threaded              __          Coarse
# 8                    3/16"  Fully Threaded              __          Coarse
# 9                     1/4"  Fully Threaded              __          Coarse
#
#       4       5          6                     7                      8   \
# 0   Head
# 1   Dia.     Ht.  DriveSize  TensileStrength, psi     Specifications Met
# 2
# 3
# 4  9/64"  0.086"      5/64"               170,000              ASTM A574
# 5  9/64"  0.086"      5/64"               170,000  ASME B18.3, ASTM A574
# 6  9/64"  0.086"      5/64"               170,000              ASTM A574
# 7  9/64"  0.086"      5/64"               170,000              ASTM A574
# 8  9/64"  0.086"      5/64"               170,000              ASTM A574
# 9  9/64"  0.086"      5/64"               170,000              ASTM A574
#
#          9          10      11
# 0
# 1  Pkg.Qty.               Pkg.
# 2
# 3
# 4        25  91251A213  $17.91
# 5         5  91251A470   19.00
# 6        25  91251A072   11.51
# 7        10  91864A010   11.12
# 8       100  91251A076    8.93
# 9       100  91251A077    9.08

# %%
features_wid_na=[feature for feature in data.columns if data[feature].isnull().sum()>1]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 features_wid_na=[feature for feature in data.columns if data[feature].isnull().sum()>1]
#
# AttributeError: 'list' object has no attribute 'columns'

# %%
for feature in features_wid_na:
    print(feature, np.round(data[feature].isnull().mean(),4),'% missing value')
# Out:
# 1 0.1837 % missing value
# 2 0.1837 % missing value
# 3 0.1837 % missing value
# 4 0.1837 % missing value
# 5 0.4082 % missing value
# 6 0.449 % missing value
# 7 0.449 % missing value
# 8 0.4694 % missing value
# 9 0.4694 % missing value
# 10 0.4694 % missing value
# 11 0.8367 % missing value
# 12 0.8571 % missing value
# 13 0.8571 % missing value
# 14 0.898 % missing value
# 15 0.898 % missing value
# 16 0.9184 % missing value
# 17 0.9796 % missing value
# 18 0.9796 % missing value
# 19 0.9796 % missing value
# 20 0.9796 % missing value
# 21 0.9796 % missing value
# 22 0.9796 % missing value
# 23 0.9796 % missing value
# 24 0.9796 % missing value
# 25 0.9796 % missing value
# 26 0.9796 % missing value
# 27 0.9796 % missing value
# 28 0.9796 % missing value
# 29 0.9796 % missing value
# 30 0.9796 % missing value
# 31 0.9796 % missing value
# 32 0.9796 % missing value
# 33 0.9796 % missing value
# 34 0.9796 % missing value
# 35 0.9796 % missing value
# 36 0.9796 % missing value
# 37 0.9796 % missing value

# %%
# Total count of missing values:
data.isnull().sum()
# Out:
# 0      1
# 1      9
# 2      9
# 3      9
# 4      9
# 5     20
# 6     22
# 7     22
# 8     23
# 9     23
# 10    23
# 11    41
# 12    42
# 13    42
# 14    44
# 15    44
# 16    45
# 17    48
# 18    48
# 19    48
# 20    48
# 21    48
# 22    48
# 23    48
# 24    48
# 25    48
# 26    48
# 27    48
# 28    48
# 29    48
# 30    48
# 31    48
# 32    48
# 33    48
# 34    48
# 35    48
# 36    48
# 37    48
# dtype: int64
