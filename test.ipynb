# %%
from misumi_category_data import get_all_data

# %%
data=get_all_data()
# Out:
# Processing time: 0.11 seconds

# %%
data.head()
# Out:
#                      0                        1             2         3   \
# 0  Thread Size - Metric                        8    Length(mm)        30
# 1           Drive Style  [Hex Socket] Hex Socket  Head Profile  Standard
# 2  Thread Size - Metric                        6    Length(mm)        30
# 3  Thread Size - Metric                        8    Length(mm)        30
# 4  Thread Size - Metric                        2    Length(mm)         4
#
#              4                        5             6         7            8   \
# 0   Drive Style               Hex Socket  Head Profile  Standard     Material
# 1      Material      304 Stainless Steel        Finish     Plain  Thread Type
# 2  Head Profile                Extra Low        Finish     Plain  Thread Type
# 3   Drive Style               Hex Socket  Head Profile  Standard     Material
# 4   Drive Style  [Hex Socket] Hex Socket  Head Profile  Standard     Material
#
# ...
